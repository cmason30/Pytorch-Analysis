# %% [markdown]
# <a href="https://colab.research.google.com/github/cmason30/Pytorch-Analysis/blob/main/Pytorch_SLR_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import torch
import torch.nn as nn
from sklearn import datasets
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
re_train = pd.read_csv('train (1).csv', usecols=['GrLivArea', 'SalePrice'])
re_train = (np.log(re_train)).replace(-np.inf, 0)

x_numpy = re_train['GrLivArea'].to_numpy().reshape(-1,1)
y_numpy = re_train['SalePrice'].to_numpy().reshape(-1,1)

# %%
X = torch.from_numpy(x_numpy.astype(np.float32))
y = torch.from_numpy(y_numpy.astype(np.float32))

# %%
n_samples, n_features = X.shape

# %%
input_size = n_features
output_size = 1
model = nn.Linear(input_size, output_size)
learning_rate = .01

# %%
loss_fn = nn.MSELoss()
opt = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
epochs = 100

for epoch in range(epochs):
  # Forward pass and loss
  y_pred = model(X)
  loss = loss_fn(y_pred, y)

  # backward pass
  loss.backward()

  # update
  opt.step()
  opt.zero_grad()

  if (epoch+1) % 10 == 0:
    print(f'epoch: {epoch +1}, loss = {loss.item():.4f}')

predicted = model(X).detach().numpy()
np.exp(predicted)
# Out:
# epoch: 10, loss = 0.1186
# epoch: 20, loss = 0.1185
# epoch: 30, loss = 0.1185
# epoch: 40, loss = 0.1185
# epoch: 50, loss = 0.1184
# epoch: 60, loss = 0.1184
# epoch: 70, loss = 0.1184
# epoch: 80, loss = 0.1183
# epoch: 90, loss = 0.1183
# epoch: 100, loss = 0.1183
# array([[215271.73],
#        [136411.06],
#        [229798.97],
#        ...,
#        [344791.2 ],
#        [107663.54],
#        [135438.34]], dtype=float32)
